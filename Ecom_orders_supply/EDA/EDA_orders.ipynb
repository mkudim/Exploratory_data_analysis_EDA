# %% [markdown]
# # Таблица orders

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_o = pd.read_csv('../raw_data/df_Orders.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df_o.shape
# Out:
# (89316, 7)

# %%
df_o.size
# Out:
# 625212

# %%
df_o.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_timestamp',
#        'order_estimated_delivery_date'],
#       dtype='str')

# %%
df_o.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       89316 non-null  str
#  1   customer_id                    89316 non-null  str
#  2   order_status                   89316 non-null  str
#  3   order_purchase_timestamp       89316 non-null  str
#  4   order_approved_at              89307 non-null  str
#  5   order_delivered_timestamp      87427 non-null  str
#  6   order_estimated_delivery_date  89316 non-null  str
# dtypes: str(7)
# memory usage: 4.8 MB

# %%
df_o.head()
# Out:
#        order_id   customer_id order_status order_purchase_timestamp  \
# 0  Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1  v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2  Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3  bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4  Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
#
#      order_approved_at order_delivered_timestamp order_estimated_delivery_date
# 0  2017-10-22 19:14:13       2017-10-26 22:19:52                    2017-11-09
# 1  2018-06-20 22:20:20       2018-07-03 22:51:22                    2018-07-24
# 2  2018-02-17 16:15:35       2018-02-27 01:29:50                    2018-03-08
# 3  2018-08-18 18:15:16       2018-08-27 20:03:51                    2018-09-19
# 4  2017-12-22 17:31:31       2018-01-05 19:22:49                    2018-01-18

# %%
df_o.tail()
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#          order_approved_at order_delivered_timestamp  \
# 89311  2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312  2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313  2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314  2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315  2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date
# 89311                    2018-09-04
# 89312                    2018-01-04
# 89313                    2018-08-01
# 89314                    2018-08-17
# 89315                    2018-07-05

# %%
df_o.sample(10)
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 49490  tZ0nQo7o4GO8  NC4CNIukoGvi    delivered      2018-06-12 00:38:07
# 6589   EG8rfig2ZHzA  BFJdkeutd77G    delivered      2018-07-21 21:41:25
# 52736  tztTcuTLolZ1  SMd35JuZen7b    delivered      2017-02-10 16:05:24
# 36134  lflNv1oPnlFp  JBU7gGPG1N4w    delivered      2018-06-16 23:42:25
# 50956  2MTgLtLAZuq9  Ri3IHzsATWso    delivered      2017-11-25 21:44:49
# 36303  hoWQRPChJetn  fnbff6i3J5S1    delivered      2018-01-23 22:06:04
# 7671   HePlhEXxS9qT  2JKIqax0xwLi    delivered      2018-06-19 08:26:08
# 64496  HKBuxaDQJLsl  IqkucUcvWSgO    delivered      2018-06-27 07:14:45
# 63217  HpJ19G7umh2c  XlXKsT3TGaq4    delivered      2018-05-14 13:25:29
# 78202  REH6Ezv6HJKk  PSoWCDYRnoHv    delivered      2018-01-08 21:39:41
#
#          order_approved_at order_delivered_timestamp  \
# 49490  2018-06-12 14:45:45       2018-06-14 15:36:47
# 6589   2018-07-21 22:25:11       2018-07-26 17:51:05
# 52736  2017-02-10 16:15:17       2017-02-16 10:18:50
# 36134  2018-06-16 23:55:11       2018-07-05 07:02:52
# 50956  2017-11-25 22:31:38       2017-12-13 19:47:21
# 36303  2018-01-23 22:16:29       2018-01-31 23:24:40
# 7671   2018-06-20 08:56:29       2018-06-29 18:36:46
# 64496  2018-06-27 10:52:05       2018-07-03 15:57:08
# 63217  2018-05-14 13:35:22       2018-05-24 15:42:03
# 78202  2018-01-08 21:48:44       2018-02-07 17:08:25
#
#       order_estimated_delivery_date
# 49490                    2018-06-28
# 6589                     2018-08-08
# 52736                    2017-03-13
# 36134                    2018-08-06
# 50956                    2017-12-18
# 36303                    2018-02-15
# 7671                     2018-07-03
# 64496                    2018-07-18
# 63217                    2018-06-04
# 78202                    2018-02-07

# %%
df_o.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_timestamp',
#        'order_estimated_delivery_date'],
#       dtype='str')

# %%
# переименуем колонки для удобства
df_o = df_o.rename(columns={
                   'order_purchase_timestamp': 'purchased_date',
                   'order_approved_at': 'approved_at_date',
                   'order_delivered_timestamp': 'delivered_date',
                   'order_estimated_delivery_date': 'estimated_delivery_date'}
                   )

df_o.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'purchased_date',
#        'approved_at_date', 'delivered_date', 'estimated_delivery_date'],
#       dtype='str')

# %%
# переопределим тип у колонок с датами
date_cols = [
    'purchased_date',
    'approved_at_date',
    'delivered_date',
    'estimated_delivery_date'
]

df_o[date_cols] = df_o[date_cols].apply(pd.to_datetime)

df_o.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_id                 89316 non-null  str
#  1   customer_id              89316 non-null  str
#  2   order_status             89316 non-null  str
#  3   purchased_date           89316 non-null  datetime64[us]
#  4   approved_at_date         89307 non-null  datetime64[us]
#  5   delivered_date           87427 non-null  datetime64[us]
#  6   estimated_delivery_date  89316 non-null  datetime64[us]
# dtypes: datetime64[us](4), str(3)
# memory usage: 4.8 MB

# %%
# проверим отсутствующие значения
df_o.isna().sum()

# в датасете есть отсутствующие значения, и они достаточно логичны:
# 9 заказов еще ожидает подтверждения
# 1889 заказов еще находятся в пути до клиента
# Out:
# order_id                      0
# customer_id                   0
# order_status                  0
# purchased_date                0
# approved_at_date              9
# delivered_date             1889
# estimated_delivery_date       0
# dtype: int64

# %%
# проверим дубликаты
df_o.duplicated().sum()
# Out:
# np.int64(0)

# %%
# проверим уникальные значения
df_o.nunique()
# Out:
# order_id                   89316
# customer_id                89316
# order_status                   7
# purchased_date             72775
# approved_at_date           68215
# delivered_date             71143
# estimated_delivery_date      444
# dtype: int64

# %%
df_o['order_status'].unique()
# Out:
# <StringArray>
# [  'delivered',    'canceled',     'shipped',  'processing',    'invoiced',
#  'unavailable',    'approved']
# Length: 7, dtype: str

# %%
# переведем данные в столбце 'order_status' в тип данных 'категория'
df_o['order_status'] = df_o['order_status'].astype('category')
df_o.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_id                 89316 non-null  str
#  1   customer_id              89316 non-null  str
#  2   order_status             89316 non-null  category
#  3   purchased_date           89316 non-null  datetime64[us]
#  4   approved_at_date         89307 non-null  datetime64[us]
#  5   delivered_date           87427 non-null  datetime64[us]
#  6   estimated_delivery_date  89316 non-null  datetime64[us]
# dtypes: category(1), datetime64[us](4), str(2)
# memory usage: 4.2 MB

# %%
df_o.describe()
# Out:
#                    purchased_date            approved_at_date  \
# count                       89316                       89307
# mean   2017-12-28 18:48:18.752743  2017-12-29 06:00:09.620600
# min           2016-09-04 21:15:19         2016-10-04 09:43:32
# 25%           2017-09-08 16:33:39         2017-09-09 08:55:11
# 50%           2018-01-16 16:13:36         2018-01-16 21:51:29
# 75%           2018-05-02 12:20:40  2018-05-02 20:53:52.500000
# max           2018-09-03 09:06:57         2018-09-03 17:40:06
#
#                    delivered_date     estimated_delivery_date
# count                       87427                       89316
# mean   2018-01-11 07:17:59.921992  2018-01-21 16:16:51.850060
# min           2016-10-11 13:46:32         2016-10-20 00:00:00
# 25%    2017-09-20 20:10:47.500000         2017-09-29 00:00:00
# 50%           2018-01-30 22:38:23         2018-02-14 00:00:00
# 75%           2018-05-14 15:53:52         2018-05-24 00:00:00
# max           2018-10-17 13:22:46         2018-10-25 00:00:00

# %%
# посмотрим распределение по статусам
status_summary = (
    df_o['order_status']
    .value_counts()
    .to_frame(name='order_count')
    .reset_index()
    .rename(columns={'index': 'order_status'})
)

status_summary['share_pct'] = (
    status_summary['order_count']
    / status_summary['order_count'].sum()
    * 100
)

status_summary = status_summary.sort_values('order_count', ascending=False)

status_summary
# Out:
#   order_status  order_count  share_pct
# 0    delivered        87428  97.886157
# 1      shipped          936   1.047965
# 2     canceled          409   0.457925
# 3   processing          273   0.305656
# 4     invoiced          266   0.297819
# 5     approved            2   0.002239
# 6  unavailable            2   0.002239

# %%
# посмотрим пустые значения в датах
missing_dates = (
    df_o[date_cols]
    .isna()
    .sum()
    .to_frame(name='missing_count')
)

missing_dates['missing_share_pct'] = (
    missing_dates['missing_count']
    / len(df_o)
    * 100
).round(2)

missing_dates = missing_dates.sort_values('missing_share_pct', ascending=False)

missing_dates
# Out:
#                          missing_count  missing_share_pct
# delivered_date                    1889               2.11
# approved_at_date                     9               0.01
# purchased_date                       0               0.00
# estimated_delivery_date              0               0.00

# %%
# проверяем в каких статусах отсутствуют значения в колонке approved_at
mask = df_o['approved_at_date'].isna()

df_o.loc[mask, 'order_status'].value_counts()

# видим, что у нас имеется 9 доставленных заказов, которые не прошли этап согласования
# Out:
# order_status
# delivered      9
# approved       0
# canceled       0
# invoiced       0
# processing     0
# shipped        0
# unavailable    0
# Name: count, dtype: int64

# %%
# проверяем в каких статусах отсутствуют значения в колонке delivered
mask = df_o['delivered_date'].isna()

df_o.loc[mask, 'order_status'].value_counts()

# в основном пропуски логичные, кроме 6 заказов delivered.
# заказы имеют статус delivered, но при этом отсутствуют даты в столбце delivered
# Out:
# order_status
# shipped        936
# canceled       404
# processing     273
# invoiced       266
# delivered        6
# approved         2
# unavailable      2
# Name: count, dtype: int64

# %%
df_o.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'purchased_date',
#        'approved_at_date', 'delivered_date', 'estimated_delivery_date'],
#       dtype='str')

# %%
# рассчитаем длительность этапов заказа
df_o['dt_purchased_approved'] = (df_o['approved_at_date'] - df_o['purchased_date']).dt.days.astype('float')
df_o['dt_approved_delivered'] = (df_o['delivered_date'] - df_o['approved_at_date']).dt.days.astype('float')
df_o['dt_purchased_estimated'] = (df_o['estimated_delivery_date'] - df_o['purchased_date']).dt.days.astype('float')

df_o.head()
# Out:
#        order_id   customer_id order_status      purchased_date  \
# 0  Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered 2017-10-22 18:57:54
# 1  v6px92oS8cLG  PxA7fv9spyhx    delivered 2018-06-20 21:40:31
# 2  Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered 2018-02-16 16:19:31
# 3  bwJVWupf2keN  EOEsCQ6QlpIg    delivered 2018-08-18 18:04:29
# 4  Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered 2017-12-22 16:44:04
#
#      approved_at_date      delivered_date estimated_delivery_date  \
# 0 2017-10-22 19:14:13 2017-10-26 22:19:52              2017-11-09
# 1 2018-06-20 22:20:20 2018-07-03 22:51:22              2018-07-24
# 2 2018-02-17 16:15:35 2018-02-27 01:29:50              2018-03-08
# 3 2018-08-18 18:15:16 2018-08-27 20:03:51              2018-09-19
# 4 2017-12-22 17:31:31 2018-01-05 19:22:49              2018-01-18
#
#    dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated
# 0                    0.0                    4.0                    17.0
# 1                    0.0                   13.0                    33.0
# 2                    0.0                    9.0                    19.0
# 3                    0.0                    9.0                    31.0
# 4                    0.0                   14.0                    26.0

# %%
df_o.dtypes
# Out:
# order_id                              str
# customer_id                           str
# order_status                     category
# purchased_date             datetime64[us]
# approved_at_date           datetime64[us]
# delivered_date             datetime64[us]
# estimated_delivery_date    datetime64[us]
# dt_purchased_approved             float64
# dt_approved_delivered             float64
# dt_purchased_estimated            float64
# dtype: object

# %%
# посмотрим основные статистики для разности дат, чтобы выявить аномалии
df_o[['dt_purchased_approved', 'dt_approved_delivered',
       'dt_purchased_estimated']].describe()

# dt_purchased_approved
# минимальное и среднее значение равны нулю => заказы одобряются день-в-день
# но максимальное значение равно 60 дням => редкий кейс или ошибка даты?

# dt_approved_delivered
# минимальное значение отрицательное => доставка раньше, чем одобрение
# максимальное значение 208 дней => отдаленный штат, ошибка даты или сильно проблемный заказ?

# dt_purchased_estimated
# максимальный обещанный срок 149 дней => редкая позиция?
# наверняка этот заказ и доставлялся дольше всего
# Out:
#        dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated
# count           89307.000000           87418.000000            89316.000000
# mean                0.268579              11.514654               23.529692
# std                 0.802292               9.241674                8.863175
# min                 0.000000              -7.000000                2.000000
# 25%                 0.000000               6.000000               18.000000
# 50%                 0.000000               9.000000               23.000000
# 75%                 0.000000              15.000000               28.000000
# max                60.000000             208.000000              149.000000

# %%
# рассмотрим аномалии в датах подробнее
df_o[df_o['dt_purchased_approved'] > 30]
# Out:
#            order_id   customer_id order_status      purchased_date  \
# 27659  rmbo1tI4QSfi  FM5xLRCCs67e      shipped 2016-09-04 21:15:19
# 42135  HfwGXKFBqK8v  9eIHDJ0EfBR3      shipped 2016-09-04 21:15:19
# 49665  GdpeYIWBUIgK  MDzzVSBHbHuY   processing 2017-02-03 00:04:49
# 81247  nZBpDykdpxqM  XYkeTE6l6Pet     canceled 2016-09-05 00:15:34
#
#          approved_at_date delivered_date estimated_delivery_date  \
# 27659 2016-10-07 13:18:03            NaT              2016-10-20
# 42135 2016-10-07 13:18:03            NaT              2016-10-20
# 49665 2017-04-04 10:56:48            NaT              2017-03-31
# 81247 2016-10-07 13:17:15            NaT              2016-10-28
#
#        dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated
# 27659                   32.0                    NaN                    45.0
# 42135                   32.0                    NaN                    45.0
# 49665                   60.0                    NaN                    55.0
# 81247                   32.0                    NaN                    52.0

# %%
df_o[df_o['dt_approved_delivered'] > 60].head()
# Out:
#           order_id   customer_id order_status      purchased_date  \
# 384   FkANVps9FhLR  XX2dJ9DXoJxM    delivered 2018-01-08 16:02:04
# 555   gtrzn1LyN7dM  mEDt9a4BBKAe    delivered 2017-03-31 10:53:45
# 571   pWRjBubXBYdq  IgFTw1gGD2PM    delivered 2017-02-21 23:31:27
# 772   1E3iD0TBYiQv  ND99OCtzv42A    delivered 2017-03-16 11:36:00
# 1202  A3vUK2CgNZYI  kNp3Pih6TnUJ    delivered 2018-02-03 15:48:24
#
#         approved_at_date      delivered_date estimated_delivery_date  \
# 384  2018-01-09 07:25:32 2018-04-03 17:38:54              2018-03-19
# 555  2017-04-04 06:05:09 2017-06-14 13:06:39              2017-05-04
# 571  2017-02-23 02:35:15 2017-09-19 14:36:39              2017-03-22
# 772  2017-03-16 11:36:00 2017-09-19 16:28:58              2017-04-28
# 1202 2018-02-03 16:10:36 2018-06-13 15:57:49              2018-03-01
#
#       dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated  \
# 384                     0.0                   84.0                    69.0
# 555                     3.0                   71.0                    33.0
# 571                     1.0                  208.0                    28.0
# 772                     0.0                  187.0                    42.0
# 1202                    0.0                  129.0                    25.0
#
#       is_negative_delivery_time  is_too_long_delivery_time  \
# 384                       False                      False
# 555                       False                      False
# 571                       False                       True
# 772                       False                       True
# 1202                      False                       True
#
#       is_too_long_approval_time  is_too_long_estimated  is_anomaly
# 384                       False                  False       False
# 555                       False                  False       False
# 571                       False                  False        True
# 772                       False                  False        True
# 1202                      False                  False        True

# %%
df_o[df_o['dt_purchased_estimated'] > 60].head()
# Out:
#           order_id   customer_id order_status      purchased_date  \
# 378   aMOKAbOn7YS7  xydnwS2B3vnq    delivered 2017-10-13 14:45:03
# 384   FkANVps9FhLR  XX2dJ9DXoJxM    delivered 2018-01-08 16:02:04
# 535   khb18hvvVBQJ  zIuFaia96Pe8    delivered 2018-01-24 10:47:49
# 674   UrZlJN0G0U9W  m7pUFaiCOVx0    delivered 2018-03-01 17:43:18
# 1072  dKgztiB6hmk0  zW20fFCnkKD3    delivered 2016-10-08 17:43:26
#
#         approved_at_date      delivered_date estimated_delivery_date  \
# 378  2017-10-17 04:24:35 2017-10-25 20:22:10              2018-01-11
# 384  2018-01-09 07:25:32 2018-04-03 17:38:54              2018-03-19
# 535  2018-01-24 11:12:26 2018-03-13 13:24:36              2018-03-28
# 674  2018-03-01 17:55:27 2018-03-22 22:58:45              2018-05-08
# 1072 2016-10-13 21:09:06 2016-10-26 12:58:25              2016-12-14
#
#       dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated  \
# 378                     3.0                    8.0                    89.0
# 384                     0.0                   84.0                    69.0
# 535                     0.0                   48.0                    62.0
# 674                     0.0                   21.0                    67.0
# 1072                    5.0                   12.0                    66.0
#
#       is_negative_delivery_time  is_too_long_delivery_time  \
# 378                       False                      False
# 384                       False                      False
# 535                       False                      False
# 674                       False                      False
# 1072                      False                      False
#
#       is_too_long_approval_time  is_too_long_estimated  is_anomaly
# 378                       False                  False       False
# 384                       False                  False       False
# 535                       False                  False       False
# 674                       False                  False       False
# 1072                      False                  False       False

# %%
# пометим флагами аномальные даты (отрицательные и с задержками)
# задержкой будем считать разницу дат:
# dt_purchased_approved > 30 дней
# dt_approved_delivered > 60 дней
# dt_purchased_estimated > 90 дней
df_o['is_negative_delivery_time'] = df_o['dt_approved_delivered'] < 0
df_o[df_o['is_negative_delivery_time'] == True].head()
# Out:
#           order_id   customer_id order_status      purchased_date  \
# 732   qf88tnNyUpRx  CFq5t8NmcBjF    delivered 2018-08-09 20:45:10
# 2734  X7BdF882u7jZ  qbnOeT8aP73C    delivered 2018-08-09 20:45:10
# 3311  nFPgCdm662nu  u0vVh1c2n8hP    delivered 2018-07-24 11:32:11
# 5035  18BVSbwrvOLi  Hvb9DPYz1lcE    delivered 2017-06-26 12:23:32
# 5550  TkUmHDHxzRRF  zO1p2GAV8Fx3    delivered 2018-04-22 21:15:32
#
#         approved_at_date      delivered_date estimated_delivery_date  \
# 732  2018-08-20 15:56:29 2018-08-15 14:56:43              2018-08-14
# 2734 2018-08-20 15:56:29 2018-08-15 14:56:43              2018-08-14
# 3311 2018-07-29 23:30:52 2018-07-27 18:55:57              2018-08-06
# 5035 2017-07-05 17:09:11 2017-07-03 17:53:29              2017-07-18
# 5550 2018-04-24 19:24:43 2018-04-24 15:32:26              2018-05-10
#
#       dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated  \
# 732                    10.0                   -6.0                     4.0
# 2734                   10.0                   -6.0                     4.0
# 3311                    5.0                   -3.0                    12.0
# 5035                    9.0                   -2.0                    21.0
# 5550                    1.0                   -1.0                    17.0
#
#       is_negative_delivery_time  is_too_long_delivery_time  \
# 732                        True                      False
# 2734                       True                      False
# 3311                       True                      False
# 5035                       True                      False
# 5550                       True                      False
#
#       is_too_long_approval_time  is_too_long_estimated  is_anomaly
# 732                       False                  False        True
# 2734                      False                  False        True
# 3311                      False                  False        True
# 5035                      False                  False        True
# 5550                      False                  False        True

# %%
df_o[df_o['is_negative_delivery_time'] == True].is_negative_delivery_time.count()
# Out:
# np.int64(53)

# %%
df_o['is_too_long_delivery_time'] = df_o['dt_approved_delivered'] > 90
df_o[df_o['is_too_long_delivery_time'] == True].head()
# Out:
#           order_id   customer_id order_status      purchased_date  \
# 571   pWRjBubXBYdq  IgFTw1gGD2PM    delivered 2017-02-21 23:31:27
# 772   1E3iD0TBYiQv  ND99OCtzv42A    delivered 2017-03-16 11:36:00
# 1202  A3vUK2CgNZYI  kNp3Pih6TnUJ    delivered 2018-02-03 15:48:24
# 3145  l7IXVGR1psXu  bcH6hIBROSup    delivered 2017-03-15 11:24:27
# 3963  FKUiOI5Z8SqL  CdRtpBmtiK0d    delivered 2017-05-03 19:34:48
#
#         approved_at_date      delivered_date estimated_delivery_date  \
# 571  2017-02-23 02:35:15 2017-09-19 14:36:39              2017-03-22
# 772  2017-03-16 11:36:00 2017-09-19 16:28:58              2017-04-28
# 1202 2018-02-03 16:10:36 2018-06-13 15:57:49              2018-03-01
# 3145 2017-03-15 11:24:27 2017-09-19 14:38:18              2017-04-13
# 3963 2017-05-03 19:45:10 2017-09-19 16:38:49              2017-06-07
#
#       dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated  \
# 571                     1.0                  208.0                    28.0
# 772                     0.0                  187.0                    42.0
# 1202                    0.0                  129.0                    25.0
# 3145                    0.0                  188.0                    28.0
# 3963                    0.0                  138.0                    34.0
#
#       is_negative_delivery_time  is_too_long_delivery_time  \
# 571                       False                       True
# 772                       False                       True
# 1202                      False                       True
# 3145                      False                       True
# 3963                      False                       True
#
#       is_too_long_approval_time  is_too_long_estimated  is_anomaly
# 571                       False                  False        True
# 772                       False                  False        True
# 1202                      False                  False        True
# 3145                      False                  False        True
# 3963                      False                  False        True

# %%
df_o[df_o['is_too_long_delivery_time'] == True].is_too_long_delivery_time.count()
# Out:
# np.int64(55)

# %%
df_o['is_too_long_approval_time'] = df_o['dt_purchased_approved'] > 30
df_o[df_o['is_too_long_approval_time'] == True]
# Out:
#            order_id   customer_id order_status      purchased_date  \
# 27659  rmbo1tI4QSfi  FM5xLRCCs67e      shipped 2016-09-04 21:15:19
# 42135  HfwGXKFBqK8v  9eIHDJ0EfBR3      shipped 2016-09-04 21:15:19
# 49665  GdpeYIWBUIgK  MDzzVSBHbHuY   processing 2017-02-03 00:04:49
# 81247  nZBpDykdpxqM  XYkeTE6l6Pet     canceled 2016-09-05 00:15:34
#
#          approved_at_date delivered_date estimated_delivery_date  \
# 27659 2016-10-07 13:18:03            NaT              2016-10-20
# 42135 2016-10-07 13:18:03            NaT              2016-10-20
# 49665 2017-04-04 10:56:48            NaT              2017-03-31
# 81247 2016-10-07 13:17:15            NaT              2016-10-28
#
#        dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated  \
# 27659                   32.0                    NaN                    45.0
# 42135                   32.0                    NaN                    45.0
# 49665                   60.0                    NaN                    55.0
# 81247                   32.0                    NaN                    52.0
#
#        is_negative_delivery_time  is_too_long_delivery_time  \
# 27659                      False                      False
# 42135                      False                      False
# 49665                      False                      False
# 81247                      False                      False
#
#        is_too_long_approval_time
# 27659                       True
# 42135                       True
# 49665                       True
# 81247                       True

# %%
df_o[df_o['is_too_long_approval_time'] == True].is_too_long_approval_time.count()
# Out:
# np.int64(4)

# %%
df_o['is_too_long_estimated'] = df_o['dt_purchased_estimated'] > 90
df_o[df_o['is_too_long_estimated'] == True].head()
# Out:
#            order_id   customer_id order_status      purchased_date  \
# 7390   8s4BWE1S36x3  qY7nEXEObPnP    delivered 2017-10-27 17:03:40
# 19610  BXlHv0L868zk  SF1LZwpyamGG    delivered 2017-03-23 17:36:38
# 20243  ye1XSEmG9Ub8  yf5pRipZu1ek      shipped 2017-03-14 19:23:22
# 20498  IdmJMX3QQj4O  3sOQoJyBn763   processing 2017-03-30 15:23:23
# 21858  QLPhYjdpFIXY  bMFwE7egHPZm    delivered 2017-05-23 22:28:36
#
#          approved_at_date      delivered_date estimated_delivery_date  \
# 7390  2017-10-30 15:31:19 2017-11-25 13:12:08              2018-02-02
# 19610 2017-03-24 17:45:13 2017-05-18 12:24:25              2017-06-28
# 20243 2017-03-14 19:23:22                 NaT              2017-08-04
# 20498 2017-03-30 15:35:11                 NaT              2017-08-22
# 21858 2017-05-24 22:35:08 2017-06-09 13:35:54              2017-10-11
#
#        dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated  \
# 7390                     2.0                   25.0                    97.0
# 19610                    1.0                   54.0                    96.0
# 20243                    0.0                    NaN                   142.0
# 20498                    0.0                    NaN                   144.0
# 21858                    1.0                   15.0                   140.0
#
#        is_negative_delivery_time  is_too_long_delivery_time  \
# 7390                       False                      False
# 19610                      False                      False
# 20243                      False                      False
# 20498                      False                      False
# 21858                      False                      False
#
#        is_too_long_approval_time  is_too_long_estimated  is_anomaly
# 7390                       False                   True        True
# 19610                      False                   True        True
# 20243                      False                   True        True
# 20498                      False                   True        True
# 21858                      False                   True        True

# %%
df_o[df_o['is_too_long_estimated'] == True].is_too_long_estimated.count()
# Out:
# np.int64(17)

# %%
# соберем всю информацию в одну табицу и посмотрим количество аномальных дат
date_flag_cols = ['is_negative_delivery_time',
       'is_too_long_delivery_time', 'is_too_long_approval_time',
       'is_too_long_estimated']

flag_counts = (df_o[date_flag_cols]
               .sum()
               .to_frame(name='flag_counts'))

flag_counts['flag_share_pct'] = (
    flag_counts['flag_counts']
    / len(df_o)
    * 100
    ).round(2)

flag_counts = flag_counts.sort_values('flag_counts', ascending=False)

flag_counts

# невысокие показатели аномальных дат позволяют их исключить из дальнейшего анализа в виду невозможности уточнить у бизнеса
# будь возможность уточнить у бизнеса, то первым делом я бы уточнила "негативные даты", вероятно случилась ошибка при заполнении и даты перепутали в соседних колонках
# по датам с длинной доставкой я бы посмотрела, что за продукт, куда доставлялся
# Out:
#                            flag_counts  flag_share_pct
# is_too_long_delivery_time           55            0.06
# is_negative_delivery_time           53            0.06
# is_too_long_estimated               17            0.02
# is_too_long_approval_time            4            0.00

# %%
# пометим аномальные заказы флагом и исключим их из дальнейшего анализа
df_o['is_anomaly'] = (
    df_o['is_negative_delivery_time']
    | df_o['is_too_long_delivery_time']
    | df_o['is_too_long_approval_time']
    | df_o['is_too_long_estimated']
)

df_o_clean = df_o[~df_o['is_anomaly']]
df_o_clean.head()
# Out:
#        order_id   customer_id order_status      purchased_date  \
# 0  Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered 2017-10-22 18:57:54
# 1  v6px92oS8cLG  PxA7fv9spyhx    delivered 2018-06-20 21:40:31
# 2  Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered 2018-02-16 16:19:31
# 3  bwJVWupf2keN  EOEsCQ6QlpIg    delivered 2018-08-18 18:04:29
# 4  Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered 2017-12-22 16:44:04
#
#      approved_at_date      delivered_date estimated_delivery_date  \
# 0 2017-10-22 19:14:13 2017-10-26 22:19:52              2017-11-09
# 1 2018-06-20 22:20:20 2018-07-03 22:51:22              2018-07-24
# 2 2018-02-17 16:15:35 2018-02-27 01:29:50              2018-03-08
# 3 2018-08-18 18:15:16 2018-08-27 20:03:51              2018-09-19
# 4 2017-12-22 17:31:31 2018-01-05 19:22:49              2018-01-18
#
#    dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated  \
# 0                    0.0                    4.0                    17.0
# 1                    0.0                   13.0                    33.0
# 2                    0.0                    9.0                    19.0
# 3                    0.0                    9.0                    31.0
# 4                    0.0                   14.0                    26.0
#
#    is_negative_delivery_time  is_too_long_delivery_time  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
#
#    is_too_long_approval_time  is_too_long_estimated  is_anomaly
# 0                      False                  False       False
# 1                      False                  False       False
# 2                      False                  False       False
# 3                      False                  False       False
# 4                      False                  False       False

# %%
# оценим динамику заказов по дням / месяцам
df_o_clean['date'] = df_o_clean['purchased_date'].dt.date
df_o_clean['year_month'] = df_o_clean['purchased_date'].dt.to_period('M')
df_o_clean['year'] = df_o_clean['purchased_date'].dt.year
df_o_clean['month'] = df_o_clean['purchased_date'].dt.month
df_o_clean['day'] = df_o_clean['purchased_date'].dt.day
df_o_clean['week'] = df_o_clean['purchased_date'].dt.isocalendar().week
df_o_clean['day_of_week'] = df_o_clean['purchased_date'].dt.day_name()
df_o_clean['hour'] = df_o_clean['purchased_date'].dt.hour

df_o_clean.head()
# Out:
#        order_id   customer_id order_status      purchased_date  \
# 0  Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered 2017-10-22 18:57:54
# 1  v6px92oS8cLG  PxA7fv9spyhx    delivered 2018-06-20 21:40:31
# 2  Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered 2018-02-16 16:19:31
# 3  bwJVWupf2keN  EOEsCQ6QlpIg    delivered 2018-08-18 18:04:29
# 4  Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered 2017-12-22 16:44:04
#
#      approved_at_date      delivered_date estimated_delivery_date  \
# 0 2017-10-22 19:14:13 2017-10-26 22:19:52              2017-11-09
# 1 2018-06-20 22:20:20 2018-07-03 22:51:22              2018-07-24
# 2 2018-02-17 16:15:35 2018-02-27 01:29:50              2018-03-08
# 3 2018-08-18 18:15:16 2018-08-27 20:03:51              2018-09-19
# 4 2017-12-22 17:31:31 2018-01-05 19:22:49              2018-01-18
#
#    dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated  \
# 0                    0.0                    4.0                    17.0
# 1                    0.0                   13.0                    33.0
# 2                    0.0                    9.0                    19.0
# 3                    0.0                    9.0                    31.0
# 4                    0.0                   14.0                    26.0
#
#    is_negative_delivery_time  is_too_long_delivery_time  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
#
#    is_too_long_approval_time  is_too_long_estimated  is_anomaly        date  \
# 0                      False                  False       False  2017-10-22
# 1                      False                  False       False  2018-06-20
# 2                      False                  False       False  2018-02-16
# 3                      False                  False       False  2018-08-18
# 4                      False                  False       False  2017-12-22
#
#   year_month  year  month  day  week day_of_week  hour
# 0    2017-10  2017     10   22    42      Sunday    18
# 1    2018-06  2018      6   20    25   Wednesday    21
# 2    2018-02  2018      2   16     7      Friday    16
# 3    2018-08  2018      8   18    33    Saturday    18
# 4    2017-12  2017     12   22    51      Friday    16

# %%
df_o_clean['purchased_date'].describe()
# Out:
# count                         89187
# mean     2017-12-28 19:50:54.586004
# min             2016-10-02 22:07:52
# 25%      2017-09-08 19:28:52.500000
# 50%             2018-01-16 16:38:03
# 75%      2018-05-02 12:21:08.500000
# max             2018-09-03 09:06:57
# Name: purchased_date, dtype: object

# %%
daily = df_o_clean.groupby('date').size()

plt.figure(figsize=(15, 6))
daily.plot(kind='line', marker='o', markersize=3, linewidth=1)
plt.title('Количество заказов по дням', fontsize=14)
plt.ylabel('Количество заказов')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
print(f"Всего дней: {len(daily)}")
print(f"Среднее заказов в день: {daily.mean():.2f}")
print(f"Медиана: {daily.median():.2f}")
print(f"Максимум: {daily.max()} (в {daily.idxmax()})")
print(f"Минимум: {daily.min()} (в {daily.idxmin()})")
# Out:
# Всего дней: 613
# Среднее заказов в день: 145.49
# Медиана: 136.00
# Максимум: 1074 (в 2017-11-24)
# Минимум: 1 (в 2016-10-02)

# %%
year_month = df_o_clean.groupby('year_month').size()

plt.figure(figsize=(15, 6))
year_month.plot(kind='bar', width=0.8, color='steelblue', edgecolor='black', linewidth=0.5)
plt.title('Количество заказов по месяцам', fontsize=14)
plt.ylabel('Количество заказов')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
print(f"Всего месяцев: {len(year_month)}")
print(f"Среднее заказов в месяц: {year_month.mean():.2f}")
print(f"Медиана: {year_month.median():.2f}")
print(f"Максимум: {year_month.max()} (в {year_month.idxmax()})")
print(f"Минимум: {year_month.min()} (в {year_month.idxmin()})")
# Out:
# Всего месяцев: 23
# Среднее заказов в месяц: 3877.70
# Медиана: 4027.00
# Максимум: 6832 (в 2017-11)
# Минимум: 1 (в 2016-12)

# %%
monthly_by_year = df_o_clean.groupby(['year', 'month']).size().reset_index(name='order_id')
monthly_by_year = monthly_by_year[monthly_by_year['year'].isin([2017, 2018])]

years = sorted(monthly_by_year['year'].unique())

plt.figure(figsize=(15, 6))

for year in years:
    data = monthly_by_year[monthly_by_year['year'] == year]
    plt.plot(data['month'], data['order_id'], 'o-', linewidth=2, markersize=6, label=f'{year}')

plt.title('Помесячные продажи по годам', fontsize=14)
plt.ylabel('Количество заказов')
plt.xticks(range(1, 13), ['Янв', 'Фев', 'Мар', 'Апр', 'Май', 'Июн',
                          'Июл', 'Авг', 'Сен', 'Окт', 'Ноя', 'Дек'])
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
day_of_week = df_o_clean.groupby('day_of_week').size()

ru_days = {
    'Monday': 'Понедельник',
    'Tuesday': 'Вторник',
    'Wednesday': 'Среда',
    'Thursday': 'Четверг',
    'Friday': 'Пятница',
    'Saturday': 'Суббота',
    'Sunday': 'Воскресенье'
}

en_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_of_week = day_of_week.reindex(en_order)

ru_labels = [ru_days[day] for day in day_of_week.index]

plt.figure(figsize=(15, 6))
plt.bar(range(len(day_of_week)), day_of_week.values, color='steelblue', edgecolor='black')
plt.title('Количество заказов по дням недели', fontsize=14)
plt.ylabel('Количество заказов')
plt.xticks(range(len(day_of_week)), ru_labels, rotation=0, ha='right')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
print(f"Всего заказов: {day_of_week.sum()}")
print(f"Среднее в день: {day_of_week.mean():.2f}")
print(f"Самый загруженный день: {ru_days[day_of_week.idxmax()]} ({day_of_week.max()} заказов)")
print(f"Самый спокойный день: {ru_days[day_of_week.idxmin()]} ({day_of_week.min()} заказов)")
# Out:
# Всего заказов: 89187
# Среднее в день: 12741.00
# Самый загруженный день: Вторник (14566 заказов)
# Самый спокойный день: Суббота (9584 заказов)

# %%
hourly = df_o_clean.groupby('hour').size()
hourly = hourly.reindex(range(24), fill_value=0)

plt.figure(figsize=(15, 6))
plt.bar(hourly.index, hourly.values, color='steelblue', edgecolor='black', width=0.8)
plt.title('Количество заказов по часам', fontsize=14)
plt.xlabel('Час дня')
plt.ylabel('Количество заказов')
plt.xticks(range(0, 24, 2), [f'{h}:00' for h in range(0, 24, 2)])
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
top_hours = sorted(hourly.nlargest(3).index)
print(f"Пиковые часы: {', '.join([f'{h}:00' for h in top_hours])}")
# Out:
# Пиковые часы: 11:00, 14:00, 16:00

# %%
# проверим распределение по датам в чистом датасете df_o_clean
df_o_clean[df_o_clean['order_status'] == 'delivered'][['dt_purchased_approved', 'dt_approved_delivered',
       'dt_purchased_estimated']].describe()
# Out:
#        dt_purchased_approved  dt_approved_delivered  dt_purchased_estimated
# count           87297.000000           87291.000000            87306.000000
# mean                0.263537              11.443173               23.492429
# std                 0.733811               8.675294                8.731489
# min                 0.000000               0.000000                2.000000
# 25%                 0.000000               6.000000               18.000000
# 50%                 0.000000               9.000000               23.000000
# 75%                 0.000000              14.000000               28.000000
# max                30.000000              90.000000               90.000000
