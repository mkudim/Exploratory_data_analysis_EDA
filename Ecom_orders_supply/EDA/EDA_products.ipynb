# %% [markdown]
# # Таблица products

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_pr = pd.read_csv('../raw_data/df_Products.csv')

# %%
df_pr.shape
# Out:
# (89316, 6)

# %%
df_pr.size
# Out:
# 535896

# %%
df_pr.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='str')

# %%
df_pr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             89316 non-null  str
#  1   product_category_name  89008 non-null  str
#  2   product_weight_g       89301 non-null  float64
#  3   product_length_cm      89301 non-null  float64
#  4   product_height_cm      89301 non-null  float64
#  5   product_width_cm       89301 non-null  float64
# dtypes: float64(4), str(2)
# memory usage: 4.1 MB
